# %%
#question 1

from numpy import genfromtxt
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

def ranking(T):
    
    temp_var = []
    w=np.zeros([T+1,763])
    w[0] = w_initial
    for t in range(T):
        w[t+1] = np.matmul(w[t],M_norm)
        w[t+1] = w[t+1]/np.sum(w[t+1])
    ind = w[t+1].argsort()[-25:][::-1]
    
    for i in range(0,len(ind)):
        temp_var.append({'team': TeamNames[ind[i]], 'w_final': w[t+1][ind[i]]})

    temp_var = pd.DataFrame(temp_var)
    
    return temp_var


team_scores = genfromtxt('CFB2017_scores.csv', delimiter=',')
team_scores = team_scores.astype(int)
TeamNames=[]
w_initial = np.random.uniform(0,1,[1,763])
M=np.zeros([763,763])


file = open('TeamNames.txt','r')
for i,line in enumerate(file):
    TeamNames.append(line.strip())
TeamNames=np.array(TeamNames)


for i in range(team_scores.shape[0]):

    x1 = team_scores[i][0]
    x2 = team_scores[i][1]
    x3 = team_scores[i][2]
    x4 = team_scores[i][3]
    
    if team_scores[i][1]>team_scores[i][3]:
        
        M[x1-1][x1-1] += 1 + (x2/(x2+x4))
        M[x3-1][x1-1] += 1 + (x2/(x2+x4))
        M[x3-1][x3-1] += 0 + (x4/(x2+x4))
        M[x1-1][x3-1] += 0 + (x4/(x2+x4))
    
    elif team_scores[i][1]<team_scores[i][3]: 
        
        M[x1-1][x1-1] += 0 + (x2/(x2+x4))
        M[x3-1][x1-1] += 0 + (x2/(x2+x4))
        M[x3-1][x3-1] += 1 + (x4/(x2+x4))
        M[x1-1][x3-1] += 1 + (x4/(x2+x4))
                
    else:
        
        M[x3-1][x1-1] +=  1 + (x2/(x2+x4))
        M[x3-1][x3-1] +=  1 + (x4/(x2+x4))
        M[x1-1][x1-1] +=  1 + (x2/(x2+x4))
        M[x1-1][x3-1] +=  1 + (x4/(x2+x4))

row_sums = M.sum(axis=1)
M_norm =  M / row_sums[:, np.newaxis]

print("Top 25 Teams for t=10")
result1 = ranking(10)
print(result1)

print("Top 25 Teams for t=100")
result1 = ranking(100)
print(result1)

print("Top 25 Teams for t=1000")
result1 = ranking(1000)
print(result1)

print("Top 25 Teams for t=10000")
result1 = ranking(10000)
print(result1)
# Out:
# Top 25 Teams for t=10
#                  team   w_final
# 0          MountUnion  0.016989
# 1   MaryHardin-Baylor  0.012549
# 2         StFrancisIN  0.011672
# 3          UW-Oshkosh  0.009883
# 4         Morningside  0.009722
# 5         BrockportSt  0.009562
# 6       TAMU-Commerce  0.008442
# 7       NorthDakotaSt  0.008420
# 8           IndianaPA  0.008386
# 9             Alabama  0.008160
# 10       JamesMadison  0.008038
# 11            Georgia  0.007909
# 12     DelawareValley  0.007667
# 13           Wartburg  0.007536
# 14     CentralFlorida  0.007196
# 15            Clemson  0.006751
# 16          Reinhardt  0.006705
# 17           StThomas  0.006594
# 18          OhioState  0.006342
# 19          Wisconsin  0.006301
# 20           Oklahoma  0.006237
# 21     MinnSt-Mankato  0.006109
# 22         Assumption  0.005865
# 23        Springfield  0.005657
# 24            Ashland  0.005540
# Top 25 Teams for t=100
#                   team   w_final
# 0           MountUnion  0.065391
# 1              Alabama  0.022656
# 2              Georgia  0.018986
# 3           UW-Oshkosh  0.017787
# 4            OhioState  0.014655
# 5              Clemson  0.014524
# 6             Oklahoma  0.014012
# 7            Wisconsin  0.013568
# 8       CentralFlorida  0.012878
# 9    MaryHardin-Baylor  0.012744
# 10       TAMU-Commerce  0.012397
# 11              Auburn  0.011800
# 12         StFrancisIN  0.011534
# 13           PennState  0.010557
# 14         BrockportSt  0.009613
# 15      DelawareValley  0.008079
# 16           NotreDame  0.008071
# 17       NorthDakotaSt  0.007893
# 18         FrostburgSt  0.007848
# 19                 TCU  0.007714
# 20      MinnSt-Mankato  0.007504
# 21  CaseWesternReserve  0.007120
# 22         JohnCarroll  0.006813
# 23           IndianaPA  0.006524
# 24             Harding  0.006513
# Top 25 Teams for t=1000
#               team   w_final
# 0          Alabama  0.042149
# 1          Georgia  0.034813
# 2       MountUnion  0.034089
# 3        OhioState  0.027643
# 4          Clemson  0.026809
# 5         Oklahoma  0.026095
# 6        Wisconsin  0.025605
# 7   CentralFlorida  0.023770
# 8           Auburn  0.021864
# 9        PennState  0.019800
# 10       NotreDame  0.014891
# 11             TCU  0.014202
# 12         MiamiFL  0.011865
# 13      MichiganSt  0.011735
# 14      OklahomaSt  0.011253
# 15            Iowa  0.010640
# 16    Northwestern  0.010302
# 17          IowaSt  0.010216
# 18             LSU  0.009543
# 19   NorthDakotaSt  0.009465
# 20     SouthernCal  0.009449
# 21      Washington  0.009256
# 22      UW-Oshkosh  0.009255
# 23        Stanford  0.008715
# 24   MississippiSt  0.008514
# Top 25 Teams for t=10000
#                team   w_final
# 0           Alabama  0.051005
# 1           Georgia  0.042086
# 2         OhioState  0.033492
# 3           Clemson  0.032425
# 4          Oklahoma  0.031587
# 5         Wisconsin  0.031024
# 6    CentralFlorida  0.028748
# 7            Auburn  0.026449
# 8         PennState  0.023978
# 9         NotreDame  0.018011
# 10              TCU  0.017175
# 11          MiamiFL  0.014346
# 12       MichiganSt  0.014209
# 13       OklahomaSt  0.013607
# 14             Iowa  0.012885
# 15     Northwestern  0.012478
# 16           IowaSt  0.012344
# 17              LSU  0.011540
# 18      SouthernCal  0.011414
# 19       Washington  0.011167
# 20    NorthDakotaSt  0.010916
# 21         Stanford  0.010526
# 22    MississippiSt  0.010295
# 23     VirginiaTech  0.010039
# 24  NorthCarolinaSt  0.009575

# %%
T = 10000
a,b = scipy.sparse.linalg.eigs(M_norm.T,k=1,sigma=1.0)
b = b/np.sum(b)
w = np.zeros([T+1,763])
w[0] = w_initial
for t in range(T):
    w[t+1] = np.matmul(w[t],M_norm)
    w[t+1] = w[t+1]/(np.sum(w[t+1]))

answer = []
for i in range(1,10000):
    answer.append(np.linalg.norm(w[i].reshape([763,1])-b,ord=1))

plt.figure(figsize=(8,8))    
plt.plot(np.arange(1, 10000),answer)
plt.xlabel("iterations")
plt.title(" |w(t) - w(inf)| as a function of t")
plt.show()

# %%
import numpy
def nmf_function(data_file, vocab_file, T):
    
    vocab_length = 3012
    doc_length = 8447
    d = 25
    W = numpy.random.uniform(1,2,(vocab_length,d))
    H = numpy.random.uniform(1,2,(d,doc_length))
    X = numpy.zeros((vocab_length,doc_length))
    
    temp_var = 0
    with open(data_file) as f:
        for row in f:
            nwords = row.rstrip('\n').split(',')
            for y in nwords:
                a,b = [int(x) for x in y.split(':')]
                X[a-1,temp_var] = b
            temp_var+=1
    
    with open(vocab_file) as file:
        words = numpy.array([a.rstrip('\n') for a in file.readlines()])


    obj_list = []
    WH = W.dot(H)
    temp_matrix = X/(WH+1e-16)

    for i in range(T):

        H = numpy.multiply(H, W.T.dot(temp_matrix))/numpy.sum(W,axis=0).reshape(d,1)
        WH = W.dot(H)
        temp_matrix = X/(WH+1e-16)
        W = numpy.multiply(W, temp_matrix.dot(H.T))/numpy.sum(H,axis=1).reshape(1,d)

        WH = W.dot(H)
        temp_matrix = X/(WH+1e-16)

        obj = numpy.sum(numpy.multiply(numpy.log(1/(WH+1e-16)),X) + WH)
        obj_list.append(obj)

        W = W / (numpy.sum(W, axis=0).reshape(1,-1))
        word_index = numpy.apply_along_axis(lambda x: numpy.argsort(x)[-10:][::-1],axis=0,arr=W)
        answer = pd.DataFrame(index=range(10),columns=['topic_%d'%i for i in range(1,26)])
        for i in range(25):
            answer.iloc[:,i] = list(zip([format(x, '.3f') for x in W[word_index[:,i],i]],words[word_index[:,i]]))
        
        answer.to_csv('q2_b.csv',index=False)
        
    plt.figure()
    plt.plot(range(1,T+1),obj_list)
    plt.xticks(numpy.linspace(1,T,5))
    plt.xlabel('Iterations')
    plt.title('Objective function for iterations')
    plt.show()
